# %% [markdown]
# <a href="https://colab.research.google.com/github/RanjethSundaram/Langchain/blob/main/langchain_learning_demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install langchain openai python-dotenv
# !python -m pip install langchain-google-genai

# %%
from langchain.chat_models import BaseChatModel
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
